# %%
import scanpy as sc
import sys
sys.path.append('/homefolder/deborah/Git/Spatial_transcriptomics_rep/src')
from _utils import plot_cell_type

# %%
adata = sc.read_h5ad('/homefolder/deborah/Rnd/projects/spatial/vizgen/Bioivt_pilot/Samples_annotation/HuOvarianCa-1317546B_annotated.hdf5')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 676243 × 361
#     obs: 'fov', 'volume', 'center_x', 'center_y', 'min_x', 'min_y', 'max_x', 'max_y', 'anisotropy', 'transcript_count', 'perimeter_area_ratio', 'solidity', 'barcodeCount', 'volume_factor', 'leiden', 'major_cell_type', 'minor_cell_type', 'mid_cell_type'
#     var: 'mean', 'std'
#     uns: 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(adata,color=['major_cell_type'])
# Out:
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
plot_cell_type(adata,'major_cell_type')
# Out:
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:368: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:378: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:368: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:378: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:368: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:378: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:368: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:378: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:368: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:378: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:368: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:378: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:368: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:378: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:368: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:378: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:368: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:378: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:368: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:378: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:368: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
# /homefolder/deborah/miniconda3/envs/scgen/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:378: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   ax.scatter(
